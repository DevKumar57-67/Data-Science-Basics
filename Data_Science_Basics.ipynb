# %% [markdown]
# <a href="https://colab.research.google.com/github/DevKumar57-67/Data-Science-Basics/blob/main/Data_Science_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#             DATA SCIENCE TUTORIALS

# %% [markdown]
# Data Science and Artificial Intelligence are one of the most fascinating field in the world today. In this particular course we will be looking towards the concepts of Data Science and Artificial Intelligence.

# %% [markdown]
# This course is sub-divised in the chapters:
#
# Machine Learning concepts
# Deep Learning concepts
# Natural Language Processing concepts
# Generative AI
#
# All the chapters will be covered deeply

# %% [markdown]
# Prerequisites:
# Some prerequisites are needed for learning DS and AI.
# Cover the Python Programming Language completely and then a Database and Data Structures and Algorithms in Python

# %% [markdown]
#                 MACHINE LEARNING
# * Data Science Basics
# * Data Loading
# * Data Analytics
# * Data Processing
# * Data Visualisation
# * Web Scrapping
# * Data Science Libraries
# * Pandas
# * Numpy
# * Matplotlib
# * Pyplot
# * Seaborn
# * Supervised ML
# * Unsupervised ML
# * Reinforcement ML
# * ML Algorithms

# %%
# Data Loading with pandas for csv types of files
import pandas as pd
df = pd.read_csv("/content/global_water_consumption.csv")
df.head()
# Out:
#      Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0  Indonesia  2022                                          895.15
# 1  Indonesia  2024                                          502.89
# 2      Spain  2000                                          843.39
# 3     Canada  2021                                          803.34
# 4     Brazil  2022                                          416.40
#
#    Per Capita Water Use (Liters per Day) Water Scarcity Level  \
# 0                                 489.73                  Low
# 1                                 311.95                 High
# 2                                 440.09               Medium
# 3                                 478.98                 High
# 4                                 353.91                 High
#
#    Agricultural Water Use (%)  Industrial Water Use (%)  \
# 0                       20.78                     13.75
# 1                       48.51                      8.44
# ...

# %%
#Data Analytics with CSV files
df.head(5) # for top 5 rows
# Out:
#      Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0  Indonesia  2022                                          895.15
# 1  Indonesia  2024                                          502.89
# 2      Spain  2000                                          843.39
# 3     Canada  2021                                          803.34
# 4     Brazil  2022                                          416.40
#
#    Per Capita Water Use (Liters per Day) Water Scarcity Level  \
# 0                                 489.73                  Low
# 1                                 311.95                 High
# 2                                 440.09               Medium
# 3                                 478.98                 High
# 4                                 353.91                 High
#
#    Agricultural Water Use (%)  Industrial Water Use (%)  \
# 0                       20.78                     13.75
# 1                       48.51                      8.44
# ...

# %%
df.tail(5) #for bottom 5 rows
# Out:
#         Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 4995      Japan  2018                                          959.42
# 4996      China  2018                                          642.35
# 4997         UK  2005                                          848.58
# 4998  Australia  2005                                          544.67
# 4999      Italy  2019                                          420.13
#
#       Per Capita Water Use (Liters per Day) Water Scarcity Level  \
# 4995                                 143.62                  Low
# 4996                                 444.26               Medium
# 4997                                 286.60                 High
# 4998                                 450.18                  Low
# 4999                                 198.42               Medium
#
#       Agricultural Water Use (%)  Industrial Water Use (%)  \
# 4995                       25.19                     49.05
# ...

# %%
#for knowing number of rows and columns
print(df.shape)
# Out:
# (5000, 10)

# %%
# for n rows
df = pd.read_csv("/content/global_water_consumption.csv", nrows=3)
df
# Out:
#      Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0  Indonesia  2022                                          895.15
# 1  Indonesia  2024                                          502.89
# 2      Spain  2000                                          843.39
#
#    Per Capita Water Use (Liters per Day) Water Scarcity Level  \
# 0                                 489.73                  Low
# 1                                 311.95                 High
# 2                                 440.09               Medium
#
#    Agricultural Water Use (%)  Industrial Water Use (%)  \
# 0                       20.78                     13.75
# 1                       48.51                      8.44
# 2                       25.16                     31.70
#
#    Household Water Use (%)  Rainfall Impact (Annual Precipitation in mm)  \
# 0                    34.99                                       1075.28
# ...

# %%
# for skipping the rows
df = pd.read_csv("/content/global_water_consumption.csv", skiprows=4999)
df
# Out:
#   Australia  2005  544.67  450.18     Low  64.19  18.74  21.35  1584.8  0.56
# 0     Italy  2019  420.13  198.42  Medium  53.89   9.77  10.17  2161.1  2.06

# %%
# for basic math
df.describe()
# Out:
#          2005  544.67  450.18  64.19  18.74  21.35  1584.8  0.56
# count     1.0    1.00    1.00   1.00   1.00   1.00     1.0  1.00
# mean   2019.0  420.13  198.42  53.89   9.77  10.17  2161.1  2.06
# std       NaN     NaN     NaN    NaN    NaN    NaN     NaN   NaN
# min    2019.0  420.13  198.42  53.89   9.77  10.17  2161.1  2.06
# 25%    2019.0  420.13  198.42  53.89   9.77  10.17  2161.1  2.06
# 50%    2019.0  420.13  198.42  53.89   9.77  10.17  2161.1  2.06
# 75%    2019.0  420.13  198.42  53.89   9.77  10.17  2161.1  2.06
# max    2019.0  420.13  198.42  53.89   9.77  10.17  2161.1  2.06

# %%
# for specific
df = pd.read_csv("/content/global_water_consumption.csv", usecols=["Country", "Year"])
df
# Out:
#         Country  Year
# 0     Indonesia  2022
# 1     Indonesia  2024
# 2         Spain  2000
# 3        Canada  2021
# 4        Brazil  2022
# ...         ...   ...
# 4995      Japan  2018
# 4996      China  2018
# 4997         UK  2005
# 4998  Australia  2005
# 4999      Italy  2019
#
# [5000 rows x 2 columns]

# %%
# for handling missing values

df = pd.read_csv("/content/global_water_consumption.csv", na_values=["n/a", "Unknown"])

# %% [markdown]
# #       PANDAS TUTORIALS

# %% [markdown]
# Pandas is the first library to learn in Data Science because we will be dealing with data everytime so we need pandas which is a python library to work with dataset

# %%
# importing pandas
# first step is loading dataset we are taking a CSV file
import pandas as pd
data = pd.read_csv("/content/global_water_consumption.csv")
data
# Out:
#         Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0     Indonesia  2022                                          895.15
# 1     Indonesia  2024                                          502.89
# 2         Spain  2000                                          843.39
# 3        Canada  2021                                          803.34
# 4        Brazil  2022                                          416.40
# ...         ...   ...                                             ...
# 4995      Japan  2018                                          959.42
# 4996      China  2018                                          642.35
# 4997         UK  2005                                          848.58
# 4998  Australia  2005                                          544.67
# 4999      Italy  2019                                          420.13
#
#       Per Capita Water Use (Liters per Day) Water Scarcity Level  \
# ...

# %%
# Now Data analytics
data.head()
# Out:
#      Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0  Indonesia  2022                                          895.15
# 1  Indonesia  2024                                          502.89
# 2      Spain  2000                                          843.39
# 3     Canada  2021                                          803.34
# 4     Brazil  2022                                          416.40
#
#    Per Capita Water Use (Liters per Day) Water Scarcity Level  \
# 0                                 489.73                  Low
# 1                                 311.95                 High
# 2                                 440.09               Medium
# 3                                 478.98                 High
# 4                                 353.91                 High
#
#    Agricultural Water Use (%)  Industrial Water Use (%)  \
# 0                       20.78                     13.75
# 1                       48.51                      8.44
# ...

# %%
data.tail()
# Out:
#         Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 4995      Japan  2018                                          959.42
# 4996      China  2018                                          642.35
# 4997         UK  2005                                          848.58
# 4998  Australia  2005                                          544.67
# 4999      Italy  2019                                          420.13
#
#       Per Capita Water Use (Liters per Day) Water Scarcity Level  \
# 4995                                 143.62                  Low
# 4996                                 444.26               Medium
# 4997                                 286.60                 High
# 4998                                 450.18                  Low
# 4999                                 198.42               Medium
#
#       Agricultural Water Use (%)  Industrial Water Use (%)  \
# 4995                       25.19                     49.05
# ...

# %%
data.shape
# Out:
# (5000, 10)

# %%
data.describe()
# Out:
#               Year  Total Water Consumption (Billion Cubic Meters)  \
# count  5000.000000                                     5000.000000
# mean   2012.204400                                      503.459606
# std       7.205484                                      284.457947
# min    2000.000000                                       10.050000
# 25%    2006.000000                                      259.677500
# 50%    2012.000000                                      499.515000
# 75%    2018.000000                                      751.797500
# max    2024.000000                                      999.680000
#
#        Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# count                            5000.000000                 5000.000000
# mean                              276.034040                   50.281704
# std                               129.853417                   17.397782
# ...

# %%
#function counting number of unique values
data.nunique()
# Out:
# Country                                             20
# Year                                                25
# Total Water Consumption (Billion Cubic Meters)    4866
# Per Capita Water Use (Liters per Day)             4737
# Water Scarcity Level                                 3
# Agricultural Water Use (%)                        3397
# Industrial Water Use (%)                          3033
# Household Water Use (%)                           2456
# Rainfall Impact (Annual Precipitation in mm)      4956
# Groundwater Depletion Rate (%)                     491
# dtype: int64

# %%
#function counting null values
data.isnull()
# Out:
#       Country   Year  Total Water Consumption (Billion Cubic Meters)  \
# 0       False  False                                           False
# 1       False  False                                           False
# 2       False  False                                           False
# 3       False  False                                           False
# 4       False  False                                           False
# ...       ...    ...                                             ...
# 4995    False  False                                           False
# 4996    False  False                                           False
# 4997    False  False                                           False
# 4998    False  False                                           False
# 4999    False  False                                           False
#
#       Per Capita Water Use (Liters per Day)  Water Scarcity Level  \
# 0                                     False                 False
# ...

# %%
#function counting the sum of null values
data.isnull().sum()
# Out:
# Country                                           0
# Year                                              0
# Total Water Consumption (Billion Cubic Meters)    0
# Per Capita Water Use (Liters per Day)             0
# Water Scarcity Level                              0
# Agricultural Water Use (%)                        0
# Industrial Water Use (%)                          0
# Household Water Use (%)                           0
# Rainfall Impact (Annual Precipitation in mm)      0
# Groundwater Depletion Rate (%)                    0
# dtype: int64

# %%
# All mathematical functions
# import pandas for reading csv file
# import pandas as pd

#reading csv file

#using describe function
print(data.describe())

#using count function
print(data.idxmax())

#using idxmin function
print(data.idxmin())

#count of elements having value 3
print(data.value_counts().head(3))
# Out:
#               Year  Total Water Consumption (Billion Cubic Meters)  \
# count  5000.000000                                     5000.000000
# mean   2012.204400                                      503.459606
# std       7.205484                                      284.457947
# min    2000.000000                                       10.050000
# 25%    2006.000000                                      259.677500
# 50%    2012.000000                                      499.515000
# 75%    2018.000000                                      751.797500
# max    2024.000000                                      999.680000
#
#        Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# count                            5000.000000                 5000.000000
# mean                              276.034040                   50.281704
# std                               129.853417                   17.397782
# ...

# %%
#for filling missing values
data = data.fillna(55)
data
# Out:
#         Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0     Indonesia  2022                                          895.15
# 1     Indonesia  2024                                          502.89
# 2         Spain  2000                                          843.39
# 3        Canada  2021                                          803.34
# 4        Brazil  2022                                          416.40
# ...         ...   ...                                             ...
# 4995      Japan  2018                                          959.42
# 4996      China  2018                                          642.35
# 4997         UK  2005                                          848.58
# 4998  Australia  2005                                          544.67
# 4999      Italy  2019                                          420.13
#
#       Per Capita Water Use (Liters per Day) Water Scarcity Level  \
# ...

# %%
# Syntax: df.drop(['Column1', 'Columns2'], axis=1)
# Drop columns 'B' and 'C'
df = data.drop(['Country', 'Year', 'Household Water Use (%)'], axis=1)
df
# Out:
#       Total Water Consumption (Billion Cubic Meters)  \
# 0                                             895.15
# 1                                             502.89
# 2                                             843.39
# 3                                             803.34
# 4                                             416.40
# ...                                              ...
# 4995                                          959.42
# 4996                                          642.35
# 4997                                          848.58
# 4998                                          544.67
# 4999                                          420.13
#
#       Per Capita Water Use (Liters per Day) Water Scarcity Level  \
# 0                                    489.73                  Low
# 1                                    311.95                 High
# 2                                    440.09               Medium
# ...

# %%
#Working with two different datasets
df2 = pd.read_csv("/content/NVIDIA_Stock_Volatility_2014_2024.csv")
df2
# Out:
#             Date      Close       High        Low       Open     Volume  \
# 0     2014-01-31   0.370194   0.372316   0.365242   0.365478  335348000
# 1     2014-02-03   0.365242   0.373259   0.363827   0.372787  431728000
# 2     2014-02-04   0.367364   0.368071   0.363120   0.365006  280692000
# 3     2014-02-05   0.364063   0.365949   0.361233   0.364770  214676000
# 4     2014-02-06   0.368779   0.369722   0.364063   0.364535  168380000
# ...          ...        ...        ...        ...        ...        ...
# 2536  2024-02-29  79.089577  79.967326  78.327792  79.071584  507289000
# 2537  2024-03-01  82.255676  82.276674  79.412481  79.977323  479135000
# 2538  2024-03-04  85.212837  87.670141  83.695270  84.106149  615616000
# 2539  2024-03-05  85.943665  86.076636  83.397270  85.249828  520639000
# 2540  2024-03-06  88.679016  89.702776  87.009413  88.001183  582520000
#
#       Daily_Return  Rolling_Volatility       ATR  Rolling_Mean  Upper_Band  \
# ...

# %%
# prompt: Merge datasets

import pandas as pd

# Assuming you have two dataframes, df and data2, as defined in your previous code.
# If not, replace these with your actual dataframe names and loading code.

# Method 1: Concatenation (append rows)
merged_df = pd.concat([df, df2], ignore_index=True)

# Method 2: Merging (join based on a common column)
# Identify a common column between the two dataframes.
# Replace 'common_column' with the actual name of the shared column.
# You can choose different join types ('inner', 'outer', 'left', 'right').
# Example using 'inner' join (keeps rows where the common column exists in both datasets):
# merged_df = pd.merge(df, data2, on='common_column', how='inner')

# Method 3: Joining (similar to merge, but uses index by default)
# If you want to join on the index, you can use the .join() method.
# Example:
# merged_df = df.join(data2, how='inner', lsuffix='_df', rsuffix='_data2') # lsuffix and rsuffix to distinguish column names in case of overlap

# Display the merged dataframe
merged_df

# Now you can save the merged DataFrame to a new CSV file if needed:
# merged_df.to_csv("merged_dataset.csv", index=False)
# Out:
#       Total Water Consumption (Billion Cubic Meters)  \
# 0                                             895.15
# 1                                             502.89
# 2                                             843.39
# 3                                             803.34
# 4                                             416.40
# ...                                              ...
# 7536                                             NaN
# 7537                                             NaN
# 7538                                             NaN
# 7539                                             NaN
# 7540                                             NaN
#
#       Per Capita Water Use (Liters per Day) Water Scarcity Level  \
# 0                                    489.73                  Low
# 1                                    311.95                 High
# 2                                    440.09               Medium
# ...

# %%
const = merged_df['Low'].max()
merged_df['High'] = merged_df['Low'].apply(lambda x: x/const)
df
# Out:
#       Total Water Consumption (Billion Cubic Meters)  \
# 0                                             895.15
# 1                                             502.89
# 2                                             843.39
# 3                                             803.34
# 4                                             416.40
# ...                                              ...
# 4995                                          959.42
# 4996                                          642.35
# 4997                                          848.58
# 4998                                          544.67
# 4999                                          420.13
#
#       Per Capita Water Use (Liters per Day) Water Scarcity Level  \
# 0                                    489.73                  Low
# 1                                    311.95                 High
# 2                                    440.09               Medium
# ...

# %% [markdown]
# This is for this tutorial.We will continue this course with the remaining part
#
# Code contributed by Dev!
